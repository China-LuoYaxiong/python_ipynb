# %% [markdown]
# <h1>流程控制语句<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#条件判断语句" data-toc-modified-id="条件判断语句-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>条件判断语句</a></span><ul class="toc-item"><li><span><a href="#if-语句" data-toc-modified-id="if-语句-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>if 语句</a></span><ul class="toc-item"><li><span><a href="#练习" data-toc-modified-id="练习-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>练习</a></span></li></ul></li><li><span><a href="#if--else语句" data-toc-modified-id="if--else语句-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>if- else语句</a></span></li><li><span><a href="#练习题" data-toc-modified-id="练习题-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>练习题</a></span><ul class="toc-item"><li><span><a href="#练习" data-toc-modified-id="练习-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>练习</a></span></li></ul></li><li><span><a href="#if---elif---else语句" data-toc-modified-id="if---elif---else语句-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>if - elif - else语句</a></span></li><li><span><a href="#练习题" data-toc-modified-id="练习题-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>练习题</a></span><ul class="toc-item"><li><span><a href="#练习" data-toc-modified-id="练习-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>练习</a></span></li></ul></li><li><span><a href="#if-嵌套" data-toc-modified-id="if-嵌套-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>if 嵌套</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>练习</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>练习</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![timg%20%284%29.gif](attachment:timg%20%284%29.gif)

# %% [markdown]
# ## 条件判断语句

# %% [markdown]
# ### if 语句

# %% [markdown]
# ```
# if 条件:
#     条件为真（True）执行操作
# ```

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
# Out:
# your age is 19
# adult
# 到我了

# %% [markdown]
# #### 练习

# %% [markdown]
# 先定义一个字符串作为密码。
# 再让用户输入密码，赋值到password。
# - 使用if语句判断输入的是否和密码一致，如果是则打印以下语句："密码正确，恭喜"。
# - 如果输入错误则结束if语句。

# %%
# Out:
# 请输入您的密码：cda123456
# 密码正确， 恭喜

# %% [markdown]
# &emsp;
#
# &emsp;
# ###  if- else语句

# %% [markdown]
# ```
# if 条件:
#     条件为真（True）执行操作
# else：
#     条件为假（False）执行操作
# ```

# %% [markdown]
# ![_auto_2](attachment:_auto_2)

# %% [markdown]
# 用代码来描述上面这个图

# %%
# Out:
# 请输入您的年龄：18
# 成年

# %% [markdown]
# ### 练习题

# %% [markdown]
# #### 练习

# %% [markdown]
# 先定义一个密码，再用input用户输入，使用if语句判断用户输入的是否和密码一致。
# - 如果一致则打印以下语句："密码正确，恭喜"。
# - 如果输入错误则打印："密码错误"。

# %%
# Out:
# 请输入您的密码：sfdsdf
# 密码错误！

# %% [markdown]
# #### 练习

# %% [markdown]
# ```
# 从键盘获取一个人的出生年份，如果出生年份在1990到2000之间：
# 则输出：你是90后！
# 否则输出：你不是90后！```

# %%
# Out:
# 请输入您的出生年份：1998
# 你是90后！

# %%
# Out:
# 123

# %% [markdown]
# #### 练习
# 要求：从键盘获取自己的年龄，判断是否大于或者等于18岁。
# - 如果满足条件就输出“成年了，可以去网吧了”
# - 如果不满足条件，则输出“未成年，不能入内”
#
# 提示：
# - 使用input从键盘中获取数据，并且赋值到一个变量中
# - 使用if语句，来判断 age>=18是否成立

# %%
# Out:
# 请输入您的年龄：17
# 未成年， 不能入内

# %% [markdown]
# #### 练习
# ```
# 请从键盘获取一个整数,求他的平方根，要求：
# 1 如果这个整数是大于等于0，则直接打印其平方根
# 2 否则， 打印其绝对值的平方根
# ```

# %% [markdown]
# $\pm$

# %% [markdown]
# #### 练习
# 从键盘获取三个正整数a b c 判断以a b c为边长,能否构成直角三角形

# %%
# Out:
# 请输入第一条边长：3
# 请输入第二条边长：4
# 请输入第三条边长：5
# 能够构成直角三角形！

# %% [markdown]
# #### 练习
# ```
# 从键盘获取三个边长，判断这三个边长能否构成三角形。
# ```
# ![image.png](attachment:image.png)

# %%
# Out:
# 请输入第一条边长：1
# 请输入第二条边长：2
# 请输入第三条边长：3
# 不能构成三角形

# %% [markdown]
# #### 练习
# ```
# 从键盘获取一个三位的正整数，判断其是不是水仙花数
# 水仙花数是指，每一位上的数的立方之和，就等于这个数本身，那就是水仙花数
# 比如 ：153 = 1+125+27
# 所有的水仙花数有这些：153  370  371  407
# ```

# %%
# Out:
# 请输入一个三位的整数：407
# 这是水仙花数

# %% [markdown]
# &emsp;
#
# &emsp;
# ### if - elif - else语句

# %% [markdown]
# 所以if语句的完整形式就是：
#
# ```python
# if <条件判断1>:
#     <执行1>
# elif <条件判断2>:
#     <执行2>
# elif <条件判断3>:
#     <执行3>
# else:
#     <执行4>
#
# ```

# %% [markdown]
# - if语句执行有个特点，它是从上往下判断
# - 如果在某个判断上是True，把该判断对应的语句执行后，就忽略掉剩下的elif和else
# - 所以，请测试并解释为什么下面的程序打印的是“少年”：

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
age = 14
if age >= 18:
    print('成年')
elif age >=6:
    print('少年')
elif age >= 1:
    print('小孩')
else:
    print('婴儿')
# Out:
# 少年

# %%
# Out:
# 少年

# %% [markdown]
# &emsp;
#
# &emsp;
# ### 练习题
# #### 练习
# - 输入自己的身高和体重，根据BMI公式计算自己的BMI指数：体质指数（BMI）=体重（kg）÷身高^2（m）
# - 并根据BMI指数判断自己体型：
#
# ```
# 低于18.5：过轻
# 18.5-25：正常
# 25-28：过重
# 28-32：肥胖
# 高于32：严重肥胖
# 用if-elif-else语句判断并打印结果：
# ```

# %%
# Out:
# 请输入您的体重（kg）：75
# 请输入您的身高(m):    1.75
# 24.489795918367346
# 正常

# %%
if

# %% [markdown]
# &emsp;
#
# &emsp;
# #### 练习

# %% [markdown]
# 从键盘输入一个整数的分数，判断：
# - 如果分数大于等于90, 则输出 ：优
# - 如果分数大于等于80，小于90，则输出：良
# - 如果分数大于等于70，小于80，则输出：中
# - 如果分数大于等于60，小于70，则输出：及格
# - 如果分数小于60，则输出：您还需要继续努力！

# %%
# Out:
# 请输入您的分数：67
# 及格

# %% [markdown]
# &emsp;
#
# &emsp;
# #### 练习
# ```
# 要求用 if...elif..else实现如下：
# 从键盘获取三个不相同的数，输出第二大的那个。
# ```

# %% [markdown]
# #### 练习
# ```
# 从键盘获取三个整数a b c 判断以a b c为边长,能否构成直角三角形。
# 如果能够构成直角三角形，输出谁是直角边,谁是斜边
# ```

# %%
# Out:
# 请输入一个数：3
# 请输入一个数：4
# 请输入一个数：5
# 能够构成直角三角形
# 直角边是： 3.0 4.0
# 斜边是： 5.0

# %% [markdown]
# &emsp;
#
# &emsp;
# ### if 嵌套

# %% [markdown]
# if嵌套
#
# 通过学习if的基本用法，已经知道了
#
# 当需要满足条件去做事情的这种情况需要使用if
# 当满足条件时做事情A，不满足条件做事情B的这种情况使用if-else
# 想一想有这样一个场景：
# 一个小姐姐想坐公交去天安门，那么需要的是小姐姐卡上的余额大于2元，这才能上公交车；
# 之后呢如果车上有座位，小姐姐才能坐下。
# 即实际的情况某个判断是再另外一个判断成立的基础上进行的，这样的情况该怎样解决呢？
#
# 答：
#
# if嵌套

# %% [markdown]
# **代码描述上述场景**

# %%
# Out:
# 请输入卡上的余额：4
# 亲输入空座位数：0
# 站着去天安门

# %% [markdown]
# if嵌套的格式
# ```python
#  if 条件1:
#
#         满足条件1 做的事情1
#         满足条件1 做的事情2
#         ...(省略)...
#
#         if 条件2:
#             满足条件2 做的事情1
#             满足条件2 做的事情2
#             ...(省略)...
#
# ```

# %% [markdown]
# &emsp;
#
# &emsp;
# ### 练习
# 用if嵌套的方法实现以下功能：
# - 输入一个整数，判断是否为8，如果是，则打印：“对啦”
# - 如果不是，则继续判断：
#     - 输入的整数如果大于8，则打印：“比8大了”
#     - 输入的整数如果小于8，则打印：“比8小了”

# %%
# Out:
# 请输入一个整数：3
# 比8小了

# %% [markdown]
# ### 练习

# %% [markdown]
# 情景描述：
# 最近呢，小姐姐在学习Python，所以呢小姐姐呢想去淘宝上买一本Python的书。假设这本书88元。
# 于是就需要两个步骤：
# 第一：小姐姐需要输入用户名和密码，登录淘宝。
# 要求键盘输入用户名和密码
# 如果用户名=='CDA漂亮小姐姐'  并且  密码=='CDA123456'
# 则打印“欢迎，CDA漂亮小姐姐” ，否则 打印 用户名或密码错误！
# 第二：如果登录成功，请键盘输入卡上余额
# 如果余额大于等于88，则输出 下单成功
# 否则 输出 余额不足

# %%
# Out:
# 请输入您的用户名：CDA漂流小姐姐
# 请输入您的密码：  CDA123456
# 欢迎， CDA漂流小姐姐
# 请输入您的余额：90
# 下单成功
