# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#数据库简介" data-toc-modified-id="数据库简介-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>数据库简介</a></span></li><li><span><a href="#mysql-connector-python" data-toc-modified-id="mysql-connector-python-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>mysql-connector-python</a></span><ul class="toc-item"><li><span><a href="#第一步导包" data-toc-modified-id="第一步导包-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>第一步导包</a></span></li><li><span><a href="#连接数据库" data-toc-modified-id="连接数据库-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>连接数据库</a></span></li><li><span><a href="#创建游标对象" data-toc-modified-id="创建游标对象-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>创建游标对象</a></span><ul class="toc-item"><li><span><a href="#调用游标对象的execute()方法执行sql语句" data-toc-modified-id="调用游标对象的execute()方法执行sql语句-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>调用游标对象的execute()方法执行sql语句</a></span><ul class="toc-item"><li><span><a href="#创建数据库" data-toc-modified-id="创建数据库-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>创建数据库</a></span></li><li><span><a href="#查看当前的所有数据库" data-toc-modified-id="查看当前的所有数据库-2.3.1.2"><span class="toc-item-num">2.3.1.2&nbsp;&nbsp;</span>查看当前的所有数据库</a></span></li><li><span><a href="#输出查询结果的一些方法" data-toc-modified-id="输出查询结果的一些方法-2.3.1.3"><span class="toc-item-num">2.3.1.3&nbsp;&nbsp;</span>输出查询结果的一些方法</a></span></li><li><span><a href="#删除数据库" data-toc-modified-id="删除数据库-2.3.1.4"><span class="toc-item-num">2.3.1.4&nbsp;&nbsp;</span>删除数据库</a></span></li><li><span><a href="#使用数据库" data-toc-modified-id="使用数据库-2.3.1.5"><span class="toc-item-num">2.3.1.5&nbsp;&nbsp;</span>使用数据库</a></span></li><li><span><a href="#建表" data-toc-modified-id="建表-2.3.1.6"><span class="toc-item-num">2.3.1.6&nbsp;&nbsp;</span>建表</a></span></li><li><span><a href="#查看所有的表" data-toc-modified-id="查看所有的表-2.3.1.7"><span class="toc-item-num">2.3.1.7&nbsp;&nbsp;</span>查看所有的表</a></span></li><li><span><a href="#往表fruits中插入数据" data-toc-modified-id="往表fruits中插入数据-2.3.1.8"><span class="toc-item-num">2.3.1.8&nbsp;&nbsp;</span>往表fruits中插入数据</a></span></li><li><span><a href="#查询" data-toc-modified-id="查询-2.3.1.9"><span class="toc-item-num">2.3.1.9&nbsp;&nbsp;</span>查询</a></span></li><li><span><a href="#关闭游标对象和连接对象" data-toc-modified-id="关闭游标对象和连接对象-2.3.1.10"><span class="toc-item-num">2.3.1.10&nbsp;&nbsp;</span>关闭游标对象和连接对象</a></span></li></ul></li></ul></li><li><span><a href="#练习" data-toc-modified-id="练习-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>练习</a></span><ul class="toc-item"><li><span><a href="#创建一个数据库--学生管理系统" data-toc-modified-id="创建一个数据库--学生管理系统-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>创建一个数据库  <strong>学生管理系统</strong></a></span></li><li><span><a href="#使用该数据库" data-toc-modified-id="使用该数据库-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>使用该数据库</a></span></li><li><span><a href="#建表-学生信息表" data-toc-modified-id="建表-学生信息表-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>建表 <strong>学生信息表</strong></a></span></li><li><span><a href="#向表中插入数据如下：" data-toc-modified-id="向表中插入数据如下：-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>向表中插入数据如下：</a></span></li><li><span><a href="#查询-学生信息表-的所有内容" data-toc-modified-id="查询-学生信息表-的所有内容-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>查询 学生信息表 的所有内容</a></span></li><li><span><a href="#建表-账号密码表" data-toc-modified-id="建表-账号密码表-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>建表 <strong>账号密码表</strong></a></span></li><li><span><a href="#向表中插入数据如下：" data-toc-modified-id="向表中插入数据如下：-2.4.7"><span class="toc-item-num">2.4.7&nbsp;&nbsp;</span>向表中插入数据如下：</a></span></li><li><span><a href="#查询-账号密码表-的所有内容" data-toc-modified-id="查询-账号密码表-的所有内容-2.4.8"><span class="toc-item-num">2.4.8&nbsp;&nbsp;</span>查询 账号密码表 的所有内容</a></span></li><li><span><a href="#新增一个管理员5,-密码1234565" data-toc-modified-id="新增一个管理员5,-密码1234565-2.4.9"><span class="toc-item-num">2.4.9&nbsp;&nbsp;</span>新增一个管理员5, 密码1234565</a></span></li><li><span><a href="#增加一个学生的信息" data-toc-modified-id="增加一个学生的信息-2.4.10"><span class="toc-item-num">2.4.10&nbsp;&nbsp;</span>增加一个学生的信息</a></span></li><li><span><a href="#删除某个学生的信息" data-toc-modified-id="删除某个学生的信息-2.4.11"><span class="toc-item-num">2.4.11&nbsp;&nbsp;</span>删除某个学生的信息</a></span></li><li><span><a href="#修改某个学生的信息" data-toc-modified-id="修改某个学生的信息-2.4.12"><span class="toc-item-num">2.4.12&nbsp;&nbsp;</span>修改某个学生的信息</a></span></li><li><span><a href="#查询某个学生的信息" data-toc-modified-id="查询某个学生的信息-2.4.13"><span class="toc-item-num">2.4.13&nbsp;&nbsp;</span>查询某个学生的信息</a></span></li><li><span><a href="#查询两张表" data-toc-modified-id="查询两张表-2.4.14"><span class="toc-item-num">2.4.14&nbsp;&nbsp;</span>查询两张表</a></span></li><li><span><a href="#关闭游标对象和连接对象" data-toc-modified-id="关闭游标对象和连接对象-2.4.15"><span class="toc-item-num">2.4.15&nbsp;&nbsp;</span>关闭游标对象和连接对象</a></span></li></ul></li></ul></li><li><span><a href="#补充" data-toc-modified-id="补充-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>补充</a></span></li><li><span><a href="#pymysql" data-toc-modified-id="pymysql-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>pymysql</a></span><ul class="toc-item"><li><span><a href="#pymysql的安装" data-toc-modified-id="pymysql的安装-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>pymysql的安装</a></span><ul class="toc-item"><li><span><a href="#导入pymysql" data-toc-modified-id="导入pymysql-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>导入pymysql</a></span></li><li><span><a href="#创建连接对象" data-toc-modified-id="创建连接对象-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>创建连接对象</a></span></li><li><span><a href="#创建游标对象" data-toc-modified-id="创建游标对象-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>创建游标对象</a></span></li><li><span><a href="#使用数据库" data-toc-modified-id="使用数据库-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>使用数据库</a></span></li><li><span><a href="#查询" data-toc-modified-id="查询-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>查询</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 设置全部行输出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 数据库简介

# %% [markdown]
# 数据库是数据分析、数据清洗重要的数据来源，也是数据共享平台。因此学会如何从数据库获取数据、如何将数据存放到数据库还是蛮重要的。企业中的数据库各种各样，但是其原理都大同小异，因此我们这里主要介绍Python读写MySQL数据库的方法，不涉及过多数据库的 SQL 语句相关内容。
#
# mysql数据库管理系统是由服务（server）与 客户端（client）程序组成的，数据库里的数据由server管理维护，我们对数据的任何访问都需要经过服务程序处理。客户端程序则是我们与MySQL服务程序交流的桥梁，客户端程序有两大类：带交互界面的和不带交互界面的。之前大家上课使用的workbench属于有界面的MySQL客户端程序，而我们今天通过python代码编写的程序属于无界面的客户端程序。
#
# 这两类程序本质上是一样的，只是使用场景有一些区别。
#
# MySQL客户端连接服务器，有一些基本要求：
# - 服务端程序是启动的
# - 有服务端软件的IP地址、端口号、拥有一些权限的账号密码
#
# 除了MySQL之外还有很多种数据库，这些数据库跟MySQL类似，一般也得需要这些信息才能连接访问。客户端与数据库服务程序之间的通信需要一定的协议、约定，这个已经有人给写好了，因此我们只需安装相应的库就可以使用了。各个编程语言都有连接数据库的开发库：如Java里的jdbc ，在 Python 3 里面主要使用 MySQL 官方的 **mysql-connector-python** 或者 **pymysql** 这两个库。

# %% [markdown]
# # mysql-connector-python

# %% [markdown]
# mysql-connector-python是 MySQL 官方提供的驱动器
# https://pypi.org/project/mysql-connector-python/#files

# %% [markdown]
# **安装：**```命令行执行   pip install mysql-connector-python -i https://pypi.douban.com/simple```

# %% [markdown]
# ## 第一步导包

# %%
pip install mysql-connector-python -i https://pypi.douban.com/simple
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 导入包检查是否安装成功
from mysql import connector

# %% [markdown]
# ## 连接数据库

# %% [markdown]
# 可以通过**连接对象**连接数据库，这里就需要**concect()**函数

# %%
mydb = connector.connect(
  host="localhost",       # 数据库主机地址
  user="root",            # 数据库用户名
  passwd="1234"           # 数据库密码
)
 
print(mydb)

# %%
type(mydb)   # 一个MySQL数据库的连接对象
# Out:
# mysql.connector.connection_cext.CMySQLConnection

# %% [markdown]
# 这个连接对象表示，目前正在和MySQL数据库会话。

# %% [markdown]
# ## 创建游标对象

# %% [markdown]
# 通过**连接对象**的**cursor()**函数获取游标对象。
# 游标对象(Cursor Object)代表数据库中的游标，用于抓取数据库操作的上下文，主要提供执行sql语句，调用储存过程，获取查询结果等方法。

# %%
mycursor = mydb.cursor()

# %% [markdown]
# ### 调用游标对象的execute()方法执行sql语句

# %% [markdown]
# #### 创建数据库

# %%
mycursor.execute('create database test;')

# %%
mycursor.execute('create database test2;')

# %% [markdown]
# #### 查看当前的所有数据库

# %%
mycursor.execute('show databases;')   #执行了这样一个操作，但是没有返回结果出来

# %% [markdown]
# #### 输出查询结果的一些方法

# %% [markdown]
# | 方法 | 作用 |
# | :--- | :--- |
# | fetchone()	| 获取查询结果中的一条数据并从缓存区删除该条纪录，默认从第一条开始|
# | fetchmany(n)   |获取查询结果中的n条数据并从缓存区删除这些纪录	|
# | fetchall()     |	获取所有数据并清除缓存	|

# %%
mycursor.fetchone()                   # 返回结果当中的一条数据，然后删除，默认从第一条纪录开始
# Out:
# ('information_schema',)

# %%
mycursor.fetchmany(2)                 # 获取查询结果中的指定条数的纪录，并从缓存中删除这些纪录
# Out:
# [('mysql',), ('performance_schema',)]

# %%
#mycursor.fetchmany(3)

# %%
mycursor.fetchall()
# Out:
# [('sys',), ('test',), ('test2',)]

# %%
mycursor.execute('show databases;') # 再查询一次
mycursor.fetchall()                 # 直接返回所有结果
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',),
#  ('test2',)]

# %%
mycursor.fetchone()

# %%
mycursor.execute('show databases;')

# %%
for i in mycursor:             # 也可以用for循环把所有查询结果遍历输出
    print(i)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('test',)
# ('test2',)

# %% [markdown]
# **能被for循环的遍历的就可以成为可迭代对象， 可通过list()或者tuple()函数进行转化**

# %%
mycursor.execute('show databases;')

# %%
a = list(mycursor)
a
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',),
#  ('test2',)]

# %%
tuple(mycursor)
# Out:
# (('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',),
#  ('test2',))

# %% [markdown]
# #### 删除数据库

# %%
mycursor.execute('drop database test2;')    # 删除数据库 test2

# %% [markdown]
# #### 使用数据库

# %%
mycursor.execute('use test;')

# %% [markdown]
# #### 建表

# %%
# 创建一个表fruits
mycursor.execute('''
create table fruits(
                   f_id char(10) not null,
                   s_id int not null,
                   f_name varchar(255) not null,
                   f_price decimal(8,2) not null,
                   primary key(f_id)
                   );
''')

# %%
# 创建一个表emp
mycursor.execute('''
create table emp(
                depid char(3),
                depname varchar(20),
                peoplecount int
                );
''')

# %% [markdown]
# #### 查看所有的表

# %%
mycursor.execute("show tables;")

# %%
list(mycursor)    # 两张表
# Out:
# [('emp',), ('fruits',)]

# %% [markdown]
# #### 往表fruits中插入数据

# %% [markdown]
# **插入一条数据**

# %%
mycursor.execute('''
insert into fruits(f_id,s_id,f_name,f_price)
values('a1',101,'apple',5.2);
''')

# %% [markdown]
# **问题是，这样是否就插入成功了呢？我们去workbench看下**
#
# **当通过execute()方法执行表记录的增、删、改操作时，必须有一步提交的步骤，该步骤通过连接对象的commit()执行**
#
# **注意是连接对象的commit()方法**

# %%
mydb.commit()

# %% [markdown]
# 再去workbench检查下，没有问题的。

# %% [markdown]
# **插入多条数据**

# %%
mycursor.execute('''
insert into fruits(f_id,s_id,f_name,f_price)
values
        ('b1',101,'blackberry',10.2),
        ('bs1',102,'orange',11.2),
        ('bs2',105,'melon',8.2),
        ('t1',102,'banana',10.3),
        ('t2',102,'grape',5.3),
        ('o2',103,'coconut',9.2),
        ('c0',101,'cherry',3.2),
        ('a2',103,'apricot',25.2),
        ('l2',104,'lemon',6.4),
        ('b2',104,'berry',7.6),
        ('m1',106,'mango',15.6),
        ('m2',105,'xbabay',2.6),
        ('t4',107,'xbababa',3.6),
        ('b5',107,'xxxx',3.6);
''')

# %%
mydb.commit()

# %% [markdown]
# **除了这种直接在execute()方法中写sql语句的方法之外，还有一种参数的形式。**
#
# **我们先把这张fruits先删除，再重新建。**

# %%
mycursor.execute('drop table fruits;')   # 这张表已经删除了

# %% [markdown]
# **workbench中这张表已经删除了，说明这里不需要执行连接对象的commit()方法，因为删除是表，不是表里的记录**

# %%
# 创建一个表fruits
mycursor.execute('''
create table fruits(
                   f_id char(10) not null,
                   s_id int not null,
                   f_name varchar(255) not null,
                   f_price decimal(8,2) not null,
                   primary key(f_id)
                   );
''')

# %%
sql = "insert into fruits(f_id, s_id, f_name, f_price) values(%s, %s,  %s,  %s)"    # %s是占位符，无论是什么数据类型都行
val = ('a1',  101,  'apple',  5.2)
mycursor.execute(sql, val)

# %%
mydb.commit()

# %% [markdown]
# **批量插入使用 executemany() 方法，该方法的第二个参数是一个元组列表，包含了我们要插入的数据：**

# %%
sql = "insert into fruits(f_id, s_id, f_name, f_price) values(%s, %s,  %s,  %s)"    # %s是占位符，无论是什么数据类型都行
val =  [['b1',101,'blackberry',10.2],
        ('bs1',102,'orange',11.2),
        ('bs2',105,'melon',8.2),
        ('t1',102,'banana',10.3),
        ('t2',102,'grape',5.3),
        ('o2',103,'coconut',9.2),
        ('c0',101,'cherry',3.2),
        ('a2',103,'apricot',25.2),
        ('l2',104,'lemon',6.4),
        ('b2',104,'berry',7.6),
        ('m1',106,'mango',15.6),
        ('m2',105,'xbabay',2.6),
        ('t4',107,'xbababa',3.6),
        ('b5',107,'xxxx',3.6)]

# %%
val
# Out:
# [['b1', 101, 'blackberry', 10.2],
#  ('bs1', 102, 'orange', 11.2),
#  ('bs2', 105, 'melon', 8.2),
#  ('t1', 102, 'banana', 10.3),
#  ('t2', 102, 'grape', 5.3),
#  ('o2', 103, 'coconut', 9.2),
#  ('c0', 101, 'cherry', 3.2),
#  ('a2', 103, 'apricot', 25.2),
#  ('l2', 104, 'lemon', 6.4),
#  ('b2', 104, 'berry', 7.6),
#  ('m1', 106, 'mango', 15.6),
#  ('m2', 105, 'xbabay', 2.6),
#  ('t4', 107, 'xbababa', 3.6),
#  ('b5', 107, 'xxxx', 3.6)]

# %%
mycursor.executemany(sql, val)

# %%
mydb.commit()

# %% [markdown]
# #### 查询

# %%
mycursor.execute('select * from fruits;')

# %%
a = list(mycursor)

# %%
a
# Out:
# [('a1', 101, 'apple', Decimal('5.20')),
#  ('a2', 103, 'apricot', Decimal('25.20')),
#  ('b1', 101, 'blackberry', Decimal('10.20')),
#  ('b2', 104, 'berry', Decimal('7.60')),
#  ('b5', 107, 'xxxx', Decimal('3.60')),
#  ('bs1', 102, 'orange', Decimal('11.20')),
#  ('bs2', 105, 'melon', Decimal('8.20')),
#  ('c0', 101, 'cherry', Decimal('3.20')),
#  ('l2', 104, 'lemon', Decimal('6.40')),
#  ('m1', 106, 'mango', Decimal('15.60')),
#  ('m2', 105, 'xbabay', Decimal('2.60')),
#  ('o2', 103, 'coconut', Decimal('9.20')),
#  ('t1', 102, 'banana', Decimal('10.30')),
#  ('t2', 102, 'grape', Decimal('5.30')),
#  ('t4', 107, 'xbababa', Decimal('3.60'))]

# %% [markdown]
# #### 关闭游标对象和连接对象

# %%
mycursor.close()
# Out:
# True

# %%
mydb.close()

# %% [markdown]
# ## 练习

# %% [markdown]
# 利用mysql-connector-python操作MySQL数据库完成以下操作：

# %%
from mysql import connector
mydb = connector.connect(
  host="localhost",       # 数据库主机地址
  user="root",            # 数据库用户名
  passwd="1234"           # 数据库密码
)
mycursor = mydb.cursor()

# %% [markdown]
# ### 创建一个数据库  **学生管理系统**
# ```sql
# create database 学生管理系统;
# ```

# %% [markdown]
# ### 使用该数据库
# ```sql
# use 学生管理系统;
# ```

# %%
mycursor.execute('use 学生管理系统;')

# %% [markdown]
# ### 建表 **学生信息表**
# ```sql
# create table 学生信息表(
#
#               学生编号 char(10) not null,
#               学生姓名 varchar(10) not null,
#               年龄     char(10) not null,
#               性别     char(3)  not null,
#               民族     char(3)  not null,
#               政治面貌 varchar(5) not null,
#               籍贯     varchar(15) not null,
#               所在年级 varchar(10) not null,
#               电话     char(15)  not null,
#               primary key(学生编号)
#
# );
#
# ```

# %%
mycursor.execute('''
create table 学生信息表(
              学生编号 char(10) not null,
              学生姓名 varchar(10) not null,
              年龄     char(10) not null,
              性别     char(3)  not null,
              民族     char(3)  not null,
              政治面貌 varchar(5) not null,
              籍贯     varchar(15) not null,
              所在年级 varchar(10) not null,
              电话     char(15)  not null,
              primary key(学生编号)
              );
''')

# %% [markdown]
# ### 向表中插入数据如下：
# ```sql
# insert into 学生信息表
# values('s10001', '赵一', '20', '男', '汉族', '中共党员', '四川 成都', '大二', '11111111'),
#       ('s10002', '赵二', '22', '女', '回族', '共青团员', '云南 昆明', '大三', '22222222'),
#       ('s10003', '赵三', '21', '男', '汉族', '中共党员', '湖北 武汉', '大一', '33333333'),
#       ('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444'),
#       ('s10005', '赵五', '22', '男', '壮族', '共青团员', '陕西 西安', '大二', '55555555'),
#       ('s10006', '赵六', '21', '男', '汉族', '共青团员', '河南 郑州', '大二', '66666666'),
#       ('s10007', '赵七', '20', '女', '汉族', '中共党员', '湖南 长沙', '大一', '77777777');
# ```

# %%
mycursor.execute('''
insert into 学生信息表
values('s10001', '赵一', '20', '男', '汉族', '中共党员', '四川 成都', '大二', '11111111'),
      ('s10002', '赵二', '22', '女', '回族', '共青团员', '云南 昆明', '大三', '22222222'),
      ('s10003', '赵三', '21', '男', '汉族', '中共党员', '湖北 武汉', '大一', '33333333'),
      ('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444'),
      ('s10005', '赵五', '22', '男', '壮族', '共青团员', '陕西 西安', '大二', '55555555'),
      ('s10006', '赵六', '21', '男', '汉族', '共青团员', '河南 郑州', '大二', '66666666'),
      ('s10007', '赵七', '20', '女', '汉族', '中共党员', '湖南 长沙', '大一', '77777777');
''')

# %%
mydb.commit()

# %% [markdown]
# ### 查询 学生信息表 的所有内容
# ```sql
# select * from 学生信息表;
#
# ```

# %%
mycursor.execute('select * from 学生信息表;')

# %%
list(mycursor)
# Out:
# [('s10001', '赵一', '20', '男', '汉族', '中共党员', '四川 成都', '大二', '11111111'),
#  ('s10002', '赵二', '22', '女', '回族', '共青团员', '云南 昆明', '大三', '22222222'),
#  ('s10003', '赵三', '21', '男', '汉族', '中共党员', '湖北 武汉', '大一', '33333333'),
#  ('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444'),
#  ('s10005', '赵五', '22', '男', '壮族', '共青团员', '陕西 西安', '大二', '55555555'),
#  ('s10006', '赵六', '21', '男', '汉族', '共青团员', '河南 郑州', '大二', '66666666'),
#  ('s10007', '赵七', '20', '女', '汉族', '中共党员', '湖南 长沙', '大一', '77777777')]

# %% [markdown]
# ### 建表 **账号密码表**
# ```sql
# create table 账号密码表(
#
#              用户名 varchar(15) not null,
#              密码   varchar(16) not null
#
# );
# ```

# %%
mycursor.execute('''
create table 账号密码表(

             用户名 varchar(15) not null,
             密码   varchar(16) not null

);
''')

# %% [markdown]
# ### 向表中插入数据如下：
# ```sql
# insert into 账号密码表
# values('管理员1', '1234561'),
#       ('管理员2', '1234562'),
#       ('管理员3', '1234563'),
#       ('管理员4', '1234564');
# ```

# %%
mycursor.execute('''
insert into 账号密码表
values('管理员1', '1234561'),
      ('管理员2', '1234562'),
      ('管理员3', '1234563'),
      ('管理员4', '1234564');
''')

# %%
mydb.commit()

# %% [markdown]
# ### 查询 账号密码表 的所有内容
# ```sql
# select * from 账号密码表;
#
# ```

# %%
mycursor.execute('select*from 账号密码表')

# %%
list(mycursor)
# Out:
# [('管理员1', '1234561'),
#  ('管理员2', '1234562'),
#  ('管理员3', '1234563'),
#  ('管理员4', '1234564')]

# %% [markdown]
# ### 新增一个管理员5, 密码1234565
# ```sql
# insert into 账号密码表
# values('管理员5', '1234565');
# ```

# %%
mycursor.execute('''
insert into 账号密码表
values('管理员5', '1234565');
''')

# %%
mydb.commit()

# %% [markdown]
# ### 增加一个学生的信息
# ```sql
# insert into 学生信息表
# values('s10008', '赵八', '23', '男', '汉族', '群众', '北京', '大三', '88888888');
# ```

# %%
mycursor.execute('''
insert into 学生信息表
values('s10008', '赵八', '23', '男', '汉族', '群众', '北京', '大三', '88888888');
''')

# %%
mydb.commit()

# %% [markdown]
# ### 删除某个学生的信息
# ```sql
# delete from 学生信息表 where 学生编号 = 's10008';
# ```

# %%
mycursor.execute("delete from 学生信息表 where 学生编号 = 's10008';")

# %%
mydb.commit()

# %% [markdown]
# ### 修改某个学生的信息
# ```sql
# update 学生信息表 set 电话 = 19191919191 where 学生编号='s10001';
# ```

# %%
mycursor.execute("update 学生信息表 set 电话 = 19191919191 where 学生编号='s10001';")

# %%
mydb.commit()

# %% [markdown]
# ###  查询某个学生的信息
# ```sql
# select * from 学生信息表
# where 学生编号='s10004';
# ```

# %%
mycursor.execute('''
select * from 学生信息表 
where 学生编号='s10004';
''')

# %%
list(mycursor)
# Out:
# [('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444')]

# %% [markdown]
# ### 查询两张表

# %%
mycursor.execute("select*from 学生信息表")

# %%
list(mycursor)
# Out:
# [('s10001', '赵一', '20', '男', '汉族', '中共党员', '四川 成都', '大二', '19191919191'),
#  ('s10002', '赵二', '22', '女', '回族', '共青团员', '云南 昆明', '大三', '22222222'),
#  ('s10003', '赵三', '21', '男', '汉族', '中共党员', '湖北 武汉', '大一', '33333333'),
#  ('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444'),
#  ('s10005', '赵五', '22', '男', '壮族', '共青团员', '陕西 西安', '大二', '55555555'),
#  ('s10006', '赵六', '21', '男', '汉族', '共青团员', '河南 郑州', '大二', '66666666'),
#  ('s10007', '赵七', '20', '女', '汉族', '中共党员', '湖南 长沙', '大一', '77777777')]

# %%
mycursor.execute("select*from 账号密码表")

# %%
list(mycursor)
# Out:
# [('管理员1', '1234561'),
#  ('管理员2', '1234562'),
#  ('管理员3', '1234563'),
#  ('管理员4', '1234564'),
#  ('管理员5', '1234565')]

# %% [markdown]
# ### 关闭游标对象和连接对象

# %%
mycursor.close()
# Out:
# True

# %%
mydb.close()

# %% [markdown]
# # 补充

# %% [markdown]
# **如果已经存在某个数据库，可用如下代码直接访问数据库。**

# %%
mydb = connector.connect(
  host="localhost",
  user="root",
  passwd="1234",
  database="学生管理系统"
)

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute('''
select * from 学生信息表;
''')

# %%
list(mycursor)
# Out:
# [('s10001', '赵一', '20', '男', '汉族', '中共党员', '四川 成都', '大二', '19191919191'),
#  ('s10002', '赵二', '22', '女', '回族', '共青团员', '云南 昆明', '大三', '22222222'),
#  ('s10003', '赵三', '21', '男', '汉族', '中共党员', '湖北 武汉', '大一', '33333333'),
#  ('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444'),
#  ('s10005', '赵五', '22', '男', '壮族', '共青团员', '陕西 西安', '大二', '55555555'),
#  ('s10006', '赵六', '21', '男', '汉族', '共青团员', '河南 郑州', '大二', '66666666'),
#  ('s10007', '赵七', '20', '女', '汉族', '中共党员', '湖南 长沙', '大一', '77777777')]

# %% [markdown]
# # pymysql

# %% [markdown]
# **pymysql**的用法**mysql-connector-python**几乎一样，我们简单学习下就行。

# %% [markdown]
# ## pymysql的安装

# %% [markdown]
# https://pypi.org/project/PyMySQL/
# **命令行执行**：```pip install pymysql -i https://pypi.douban.com/simple```

# %%
pip install pymysql -i https://pypi.douban.com/simple
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 导入pymysql

# %%
import pymysql   # 这里没有报错就说明没有问题

# %% [markdown]
# ### 创建连接对象

# %%
mydb = pymysql.connect(  
                   host="localhost",          # 数据库主机地址
                   user="root",               # 数据库用户名
                   passwd="1234"  ,           # 数据库密码
                   )   # 数据库名称

# %% [markdown]
# ### 创建游标对象

# %%
mycursor = mydb.cursor()

# %% [markdown]
# ### 使用数据库

# %%
mycursor.execute('use 学生管理系统;')    # 会有一个返回结果,use不是查询，自然返回0
# Out:
# 0

# %%
list(mycursor)
# Out:
# []

# %% [markdown]
# ### 查询

# %%
mycursor.execute("select*from 学生信息表;")
# Out:
# 7

# %%
list(mycursor)
# Out:
# [('s10001', '赵一', '20', '男', '汉族', '中共党员', '四川 成都', '大二', '19191919191'),
#  ('s10002', '赵二', '22', '女', '回族', '共青团员', '云南 昆明', '大三', '22222222'),
#  ('s10003', '赵三', '21', '男', '汉族', '中共党员', '湖北 武汉', '大一', '33333333'),
#  ('s10004', '赵四', '24', '女', '汉族', '共青团员', '广东 深圳', '大四', '44444444'),
#  ('s10005', '赵五', '22', '男', '壮族', '共青团员', '陕西 西安', '大二', '55555555'),
#  ('s10006', '赵六', '21', '男', '汉族', '共青团员', '河南 郑州', '大二', '66666666'),
#  ('s10007', '赵七', '20', '女', '汉族', '中共党员', '湖南 长沙', '大一', '77777777')]

# %%
mycursor.execute("select* from 账号密码表;")
# Out:
# 5

# %%
list(mycursor)
# Out:
# [('管理员1', '1234561'),
#  ('管理员2', '1234562'),
#  ('管理员3', '1234563'),
#  ('管理员4', '1234564'),
#  ('管理员5', '1234565')]

# %%
mycursor.close()

# %%
mydb.close()
