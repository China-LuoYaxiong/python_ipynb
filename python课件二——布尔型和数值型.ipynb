# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#布尔型" data-toc-modified-id="布尔型-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>布尔型</a></span><ul class="toc-item"><li><span><a href="#布尔型数据的算术运算" data-toc-modified-id="布尔型数据的算术运算-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>布尔型数据的算术运算</a></span></li><li><span><a href="#布尔型数据的逻辑运算" data-toc-modified-id="布尔型数据的逻辑运算-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>布尔型数据的逻辑运算</a></span></li></ul></li><li><span><a href="#数值型" data-toc-modified-id="数值型-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>数值型</a></span><ul class="toc-item"><li><span><a href="#整型int" data-toc-modified-id="整型int-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>整型int</a></span></li><li><span><a href="#进制转换" data-toc-modified-id="进制转换-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>进制转换</a></span><ul class="toc-item"><li><span><a href="#bin()转化为二进制" data-toc-modified-id="bin()转化为二进制-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>bin()转化为二进制</a></span></li><li><span><a href="#oct()转化为八进制" data-toc-modified-id="oct()转化为八进制-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>oct()转化为八进制</a></span></li><li><span><a href="#hex()转化为16进制" data-toc-modified-id="hex()转化为16进制-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>hex()转化为16进制</a></span></li></ul></li><li><span><a href="#浮点型float" data-toc-modified-id="浮点型float-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>浮点型float</a></span><ul class="toc-item"><li><span><a href="#关于浮点数的精度问题" data-toc-modified-id="关于浮点数的精度问题-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>关于浮点数的精度问题</a></span></li></ul></li><li><span><a href="#复数型complex" data-toc-modified-id="复数型complex-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>复数型complex</a></span></li><li><span><a href="#返回复数的实部" data-toc-modified-id="返回复数的实部-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>返回复数的实部</a></span></li><li><span><a href="#返回复数的虚部" data-toc-modified-id="返回复数的虚部-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>返回复数的虚部</a></span></li><li><span><a href="#返回复数的共轭复数" data-toc-modified-id="返回复数的共轭复数-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>返回复数的共轭复数</a></span></li></ul></li><li><span><a href="#数值型数据的类型转换" data-toc-modified-id="数值型数据的类型转换-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>数值型数据的类型转换</a></span><ul class="toc-item"><li><span><a href="#转换为int型--int()" data-toc-modified-id="转换为int型--int()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>转换为int型--int()</a></span></li><li><span><a href="#转换为float型--float()" data-toc-modified-id="转换为float型--float()-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>转换为float型--float()</a></span></li></ul></li><li><span><a href="#数值型数据的计算" data-toc-modified-id="数值型数据的计算-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>数值型数据的计算</a></span><ul class="toc-item"><li><span><a href="#简单地算术运算符" data-toc-modified-id="简单地算术运算符-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>简单地算术运算符</a></span><ul class="toc-item"><li><span><a href="#练习" data-toc-modified-id="练习-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>练习</a></span></li></ul></li><li><span><a href="#比较运算符" data-toc-modified-id="比较运算符-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>比较运算符</a></span></li><li><span><a href="#复合赋值运算符" data-toc-modified-id="复合赋值运算符-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>复合赋值运算符</a></span></li><li><span><a href="#练习" data-toc-modified-id="练习-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>练习</a></span></li></ul></li><li><span><a href="#与数字相关的一些内置函数" data-toc-modified-id="与数字相关的一些内置函数-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>与数字相关的一些内置函数</a></span><ul class="toc-item"><li><span><a href="#练习" data-toc-modified-id="练习-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>练习</a></span></li></ul></li><li><span><a href="#math科学计算库" data-toc-modified-id="math科学计算库-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>math科学计算库</a></span><ul class="toc-item"><li><span><a href="#练习" data-toc-modified-id="练习-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>练习</a></span></li></ul></li></ul></div>

# %% [markdown]
# **<font color=#000000 size=3.3 face="黑体">
# Python中常用的数据类型有：**
# <font color=#00008B size=2.9 face="黑体">
#
# - 数字(Numbers)：        整数, 浮点数, 复数
#
# - 布尔(Booleans)：       True和False
#
# - 字符串(Strings)：      Uniconde字符序列, 在引号内包含
#
# - 列表(list)：           有序的值的序列
#
# - 元组(Tuples)：         有序的值的序列且不可改变
#
# - 字典(Dictionaries)：   无序的键值对的组合
#
# - 集合(Sets)：           无序的不含重复值的序列

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 设置全部行输出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 布尔型

# %% [markdown]
# - 不可变数据类型

# %% [markdown]
# ## 布尔型数据的算术运算

# %% [markdown]
# 布尔型的取值只有两个，**True** 和 **False**。
# **可以拿来做算术运算，此时等价于 1 和 0。**

# %%
True
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-2830a68c3e5e> in <module>
# ----> 1 True / False      # 自然会出现除0报错

# ZeroDivisionError: division by zero

# %%
True / False      # 自然会出现除0报错
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-2830a68c3e5e> in <module>
# ----> 1 True / False      # 自然会出现除0报错
#
# ZeroDivisionError: division by zero

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# 但是呢，基本很少把布尔型的数据拿来做算术运算，用的**更多的是做判断真假的逻辑运算**。

# %% [markdown]
# ## 布尔型数据的逻辑运算

# %% [markdown]
# 要说逻辑运算，就必须要说一些逻辑运算符。下列中 a = 10, b =20    **逻辑运算符不仅仅适用于布尔型数据**

# %% [markdown]
# | 运算符 | 逻辑表达式 | 描述 | 实例 |
# | :--- | :--- | :--- | :--- |
# | and	| x and y	| 布尔"与" - 如果 x 为 False，x and y 返回 x，否则它返回 y 。	| (a and b) 返回 20。|
# |or |	x or y	| 布尔"或" - 如果 x 是 True，它返回 x ，否则它返回 y 。	| (a or b) 返回 10。 |
# |not|	not x	| 布尔"非" - 如果 x 为 True，返回 False 。如果 x 为 False，它返回 True。 |	not(a and b) 返回 False |

# %% [markdown]
# 对于初学者来说，记忆逻辑运算符的运算规则是比较棘手的问题。
# 所以呢我们这里简单了解一下**布尔型数据的逻辑运算**

# %% [markdown]
# **计算优先级：先算not ,再算and, 最后算or**

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and False and True or True
# Out:
# True

# %%
True and not True
# Out:
# False

# %%
not True or not True
# Out:
# False

# %% [markdown]
# # 数值型

# %% [markdown]
# ## 整型int

# %% [markdown]
# Python中的整型属于int类型，，默认用十进制表示，此外，也支持二进制，八进制，十六进制表示方法。

# %%
a = 100
a
# Out:
# 100

# %%
# 查看a的数据类型
type(a)
# Out:
# int

# %%
a = 10.0
type(a)
# Out:
# float

# %% [markdown]
# 在Python中，整数(int)的值不受位数的限制，可以扩展到可用内存的限制。这与c语言是非常大的不同，c语言在定义变量的时候必须声明变量类型，以此来决定内存开辟多大的空间给它，比如，在c语言中int型默认为4个字节的储存空间，这就导致int型最大能储存的数值就是$2^{32}$,但是在python里面没有这个限制，唯一的限制是计算机的内存大小。

# %%
a =...

# %%
a
# Out:
# ...

# %% [markdown]
# ## 进制转换

# %% [markdown]
# 尽管如我们之前所说，计算机本质上只认识二进制，但是python里面的数字还是以十进制展示的，
# 当然里面给我们内置了一些方法帮我们把转换为其他进制。

# %% [markdown]
# ### bin()转化为二进制

# %%
a = bin(100)  #  0b表示这是一个二进制数
print(a)
# Out:
# 0b1100100

# %% [markdown]
# ### oct()转化为八进制

# %%
a = oct(100)  #  0o表示这是一个八进制数
print(a)
# Out:
# 0o144

# %% [markdown]
# ### hex()转化为16进制

# %%
c=hex(100)    #  0x表示这是一个十六进制数
print(c)
# Out:
# 0x64

# %%
bin(0.3)   # 小数不能直接转换成二进制,具体原因我们在浮点数的精度问题再给大家讲
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-a67557495942> in <module>
# ----> 1 bin(0.3)   # 小数不能直接转换成二进制,具体原因我们在浮点数的精度问题再给大家讲
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ## 浮点型float

# %% [markdown]
# 浮点数是属于有理数当中的，Python中的浮点数就是数学当中的小数，
# 在运算中，**整数与浮点数运算的结果依旧是浮点数**。

# %%
a = 1.11
a
# Out:
# 1.11

# %%
type(a)
# Out:
# float

# %%
c = 1.23e2
c
# Out:
# 123.0

# %%
c = 1.12323e3
c
# Out:
# 1123.23

# %%
c = 1.12323e4
c
# Out:
# 11232.3

# %%
1+1.0   # 整数与浮点数的运算结果还是浮点数
# Out:
# 2.0

# %% [markdown]
# ### 关于浮点数的精度问题

# %% [markdown]
# Python默认的是17位 精度，也就是小数点后最多16位
# 首先，这个问题并不是Python独有，其他语言也有同样的问题
# 其原因在于，小数不精准是因为在转换成二进制的过程中会产生无限循环的情况，在约省的时候就会出现误差
# 比如11.2的小数部分0.2转换为二进制是无限循环00110011001100110011....（十进制小数部分转二进制可自行百度，其实就是一个乘以2再取整的过程）

# %%
1/3
# Out:
# 0.3333333333333333

# %%
20/3
# Out:
# 6.666666666666667

# %%
a = 1.123456789123456789123456789123456789       #精度损失,只保留到小数点后16位
a
# Out:
# 1.1234567891234568

# %%
11.2+1.2
# Out:
# 12.399999999999999

# %% [markdown]
# ## 复数型complex

# %% [markdown]
# - 语法： real + imagj
# - 虚数不能单独存在，它们总是和一个值为0.0的实数部分一起构成一个复数
# - **实数部分和虚数部分都是浮点数**
# - 虚数部分必须有 j 或 J，亲测不能用i

# %%
a =3+4j
a
# Out:
# (3+4j)

# %%
type(a)
# Out:
# complex

# %% [markdown]
# ## 返回复数的实部

# %%
a.real
# Out:
# 3.0

# %% [markdown]
# ## 返回复数的虚部

# %%
a.imag
# Out:
# 4.0

# %% [markdown]
# ## 返回复数的共轭复数

# %%
a.conjugate()
# Out:
# (3-4j)

# %% [markdown]
# # 数值型数据的类型转换

# %% [markdown]
# ## 转换为int型--int()

# %% [markdown]
# - 将int(x)转换成整数类型
# - 如果x是浮点型，**小数点后面的数字都会砍掉，注意不是四舍五入**。
# - 如果想四舍五入，可以用round(x)

# %%
a = int(2.21)
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
b = input("请输入一个数字：")  
b
# Out:
# 请输入一个数字：4
# '4'

# %%
type(b)
# Out:
# str

# %%
b = int(input("请输入一个数字："))
b
# Out:
# 请输入一个数字：3
# 3

# %%
type(b)
# Out:
# int

# %%
c = int(input("请输入一个小数："))   # 小数形式的字符串不能直接通过int()转化为int型
c
# Out:
# 请输入一个小数：2.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-59d2cf398a88> in <module>
# ----> 1 c = int(input("请输入一个小数："))   # 小数形式的字符串不能直接通过int()转化为int型
#       2 c
#
# ValueError: invalid literal for int() with base 10: '2.4'

# %% [markdown]
# ## 转换为float型--float()

# %%
a = float(1234)    # 将int型转换为float型
a
# Out:
# 1234.0

# %%
type(a)
# Out:
# float

# %%
a = float('1234')   #如果字符串里是整数，可通过float()直接转化为float型
a
# Out:
# 1234.0

# %%
type(a)
# Out:
# float

# %%
a = float('1234.12')  # 如果字符串里是小数，也可通过float()直接转化为float型
a
# Out:
# 1234.12

# %%
a = float(input("请您输入一个数："))
a
# Out:
# 请您输入一个数：1.23234
# 1.23234

# %% [markdown]
# # 数值型数据的计算

# %% [markdown]
# ## 简单地算术运算符

# %% [markdown]
# 下面以a=10 ,b=20为例进行计算
#
# | 运算符 | 描述   | 实例                                                         |
# | ------ | ------ | ------------------------------------------------------------ |
# | +      | 加     | 两个对象相加 a + b 输出结果 30                               |
# | -      | 减     | 得到负数或是一个数减去另一个数 a - b 输出结果 -10            |
# | *      | 乘     | 两个数相乘或是返回一个被重复若干次的字符串 a * b 输出结果 200 |
# | /      | 除     | x除以y b / a 输出结果 2                                      |
# | //     | 取整除 | 返回商的整数部分 9//2 输出结果 4 , 9.0//2.0 输出结果 4.0     |
# | %      | 取余   | 返回除法的余数 b % a 输出结果 0                              |
# | **     | 幂     | 返回x的y次幂 a**b 为10的20次方， 输出结果 100000000000000000000 |
#
# - 乘除大于加减
# - 指数运算大于乘除

# %%
a = 100.2
b = 20

print(a/b)     #  商
print(a//b)    # 返回的是商的整数部分
print(a%b)     # 返回的是余数
# Out:
# 5.01
# 5.0
# 0.20000000000000284

# %%
2**3   # 计算的是2的3次方
# Out:
# 8

# %%
3**2
# Out:
# 9

# %% [markdown]
# ### 练习

# %% [markdown]
# **1 从键盘获取长方形的长和宽（假如都是整数），分别赋值给变量a 和 b,输出长方形的 面积 和 周长**

# %% [markdown]
# **2 从键盘获取以下:**
# - 第一个点的横坐标，x1
# - 第一个点的纵坐标，y1
# - 第二个点的横坐标，x2
# - 第二个点的纵坐标，y2
# - 最后 输出这两个点的距离

# %% [markdown]
# 设两个点其坐标为$A(x_{1},y_{1})，B(x_{2},y_{2})$,则A和B之间的距离为：
# $$
# \left | AB\right | = \sqrt{(x_{1}-x_{2})^{2}+(y_{1}-y_{2})^{2}}
# $$

# %% [markdown]
# **3 从键盘获取一个三角形的三条边长，利用海伦公式计算出这个三角形的面积**

# %% [markdown]
# ![image.png](attachment:image.png)
# **注意：不是任意的三条线段都能构成三角形，假设我们输入的都是能够构成三角形的**

# %% [markdown]
# ## 比较运算符

# %% [markdown]
#   | 运算符 | 描述                                                         | 示例                                              |
#   | ------ | ------------------------------------------------------------ | ------------------------------------------------- |
#   | ==     | 检查两个操作数的值是否相等，如果是则条件变为真。             | 如a=3,b=3则（a == b) 为 true.                     |
#   | !=     | 检查两个操作数的值是否相等，如果值不相等，则条件变为真。     | 如a=1,b=3则(a != b) 为 true.                      |
#   | >      | 检查左操作数的值是否大于右操作数的值，如果是，则条件成立。   | 如a=7,b=3则(a > b) 为 true.                       |
#   | <      | 检查左操作数的值是否小于右操作数的值，如果是，则条件成立。   | 如a=7,b=3则(a < b) 为 false.                      |
#   | >=     | 检查左操作数的值是否大于或等于右操作数的值，如果是，则条件成立。 | 如a=3,b=3则(a >= b) 为 true.                      |
#   | <=     | 检查左操作数的值是否小于或等于右操作数的值，如果是，则条件成立。 | 如a=3,b=3则(a <= b) 为 true.

# %%
a = 1
b = 2

# %%
a != b
# Out:
# True

# %%
a == True
# Out:
# True

# %%
0 >= 0
# Out:
# True

# %% [markdown]
# ## 复合赋值运算符

# %% [markdown]
# | 运算符 | 描述             | 实例                      |
# | ------ | ---------------- | ------------------------- |
# | +=     | 加法赋值运算符   | c += a 等效于 c = c + a   |
# | -=     | 减法赋值运算符   | c -= a 等效于 c = c - a   |
# | *=     | 乘法赋值运算符   | c * = a 等效于 c = c * a   |
# | /=     | 除法赋值运算符   | c /= a 等效于 c = c / a   |
# | %=     | 取模赋值运算符   | c %= a 等效于 c = c % a   |
# | **=    | 幂赋值运算符     | c ** = a 等效于 c = c ** a |
# | //=    | 取整除赋值运算符 | c //= a 等效于 c = c // a |

# %%
a = 1
a += 2    #  a = a+2
a
# Out:
# 3

# %%
a = 3
a -= 1  # a = a-1
a
# Out:
# 2

# %%
a = 10
b = 20
a /= b    # 等价于 a = a/b
a
# Out:
# 0.5

# %%
a = 10
b = 20
a *= b    #相当于a=a*b
a
# Out:
# 200

# %% [markdown]
# ## 练习

# %% [markdown]
# 思考：下面这行代码输出什么？

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # 与数字相关的一些内置函数

# %% [markdown]
# |.|python内置的一些计算函数：|
# | :---- | :-----: |
# | abs(x) | 返回x的绝对值，类型随x|
# | max(n1, n2, ...) | 返回最大值 |
# | min(n1, n2, ...) | 返回最小值 |
# | round(x [,n]) | 默认返回浮点数x的四舍五入值，如给出n值，则代表舍入到小数点后的n位。例如round(1.23456, 3)返回1.235 |
# | pow(x,y)|返回x的y次幂，即x**y|

# %%
a = abs(-2)
a
# Out:
# 2

# %%
max(1, 3, 2, 56, 7)
# Out:
# 56

# %%
min(1, 2, 34, 0, -1, -2)
# Out:
# -2

# %%
round(1.23456,4)
# Out:
# 1.2346

# %%
pow(3,2)
# Out:
# 9

# %%
pow(3,2) == 3**2
# Out:
# True

# %% [markdown]
# ## 练习

# %% [markdown]
# **从键盘获取以下：**
# - 第一个点的横坐标，x1
# - 第一个点的纵坐标，y1
# - 第二个点的横坐标，x2
# - 第二个点的纵坐标，y2
# - 最后 输出这两个点的距离

# %% [markdown]
# **用pow(x,y）来代替之前的两个***
# **设两个点其坐标为$A(x_{1},y_{1})，B(x_{2},y_{2})$,则A和B之间的距离为：**
# $$
# \left | AB\right | = \sqrt{(x_{1}-x_{2})^{2}+(y_{1}-y_{2})^{2}}
# $$

# %% [markdown]
# # math科学计算库

# %% [markdown]
# 之前我们说了，python之所能大规模的火起来，除了语法简单之外，还有就是丰富而强大的第三方库，这里呢我们先给大家介绍一个---**math**,当然math库有许多强大的计算函数，我们只介绍一些其中常用的。

# %% [markdown]
# |.. |python还提供科学计算等库，例如math，导入math库后，常用的函数有：|
# |----|-----|
# | fabs(x)|返回x的绝对值，类型是浮点数|
# |ceil(x)|取x的上入整数，如math.ceil(4.1)返回5|
# | floor(x)|取x的下入整数，如math.floor(4.9)返回4|
# | exp(x)|返回e的x次幂，e是自然常数|
# | sqrt(x)|返回x的平方根，返回值是float类型|
# | modf(x)|返回x的整数部分和小数部分，两部分的符号与x相同，整数部分以浮点型表示。例如math.modf(4.333)，返回元组(0.3330000000000002, 4.0)|
# |log10(x)|返回以10为基数的x的对数，返回值类型是浮点数|
# | log(x,y)|返回以y为基数的x的对数，返回值类型是浮点数|

# %% [markdown]
# 两个常用的常数：
# - $\pi $     在math库里可通过math.pi调用
# - 自然数e,可通过math.e调用

# %% [markdown]
# - 使用math科学计算库中的方法（math库中的函数），需要先导入math库：
#     - 导入格式：import math
#         - 使用math中的方法时，math.$*$()
#     - 导入格式： from math import *
#         - 使用math中的方法时：$*$()

# %%
import math  # 导入math 科学计算库

# %%
# 计算自然对数e的5次方
a = math.exp(5)
print(a)
# Out:
# 148.4131591025766

# %% [markdown]
# **练习：请大家从键盘获取一个整数，并赋值给x,打印出$e^{-\frac{1}{2}x^{2}}+2e$**

# %%
# 计算9的算术平方根
b = math.sqrt(9)
print(b)
# Out:
# 3.0

# %%
# 计算以10为底，10000的对数值
c = math.log10(10000)
print(c)
# Out:
# 4.0

# %%
# 可以指定对数的底数,math.log(x,a),返回以a为底，x的对数，如果不指定a，则默认以e为底数数
d = math.log(100000,10)
print(d)
# Out:
# 5.0

# %% [markdown]
# ## 练习

# %% [markdown]
# **1 从键盘获取一个数，返回这个数的整数部分和小数部分**

# %% [markdown]
# **2 从键盘获取一个数，返回这个数以自然数e为底的对数**

# %%
                       # log(x, [base=math.e]) #默然就是以e为底

# %% [markdown]
# **3 下面这个函数在神经网络中应用的非常广泛,写出这个函数，并从键盘获取x,输出对应的值**
# $$
# y = \frac{e^{x}-e^{-x}}{e^{x}+e^{-x}}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
